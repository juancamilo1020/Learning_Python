# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from urllib.request import urlopen
url = "https://www.eltiempo.com/politica/proceso-de-paz"

# %%
browser = webdriver.Chrome(r"C:\Users\juperdomo\Documents\chromedriver")
browser.get(url)
webpage = urlopen(url) 
soup = BeautifulSoup(webpage, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html>
# <head>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Casa Editorial El Tiempo" name="author"/>
# <meta content="News" name="genre"/>
# <meta content="Colombia" name="geo.placename"/>
# <meta content="4.570868;-74.297333" name="geo.position"/>
# <meta content="CO" name="geo.region"/>
# <meta content="notranslate" name="google"/>
# <meta content="4.570868, -74.297333" name="ICBM"/>
# <meta content="spanish" name="language"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@ELTIEMPO" name="twitter:site"/>
# <meta content="@ELTIEMPO" name="twitter:creator"/>
# <meta content="Proceso de paz : Noticias, Fotos y Videos de Proceso de paz - ELTIEMPO.COM" name="twitter:title"/>
# ...

# %%
import requests
r = requests.get('https://www.eltiempo.com/politica/proceso-de-paz')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all("<a class=\"boton href/>")
results
# Out:
# []

# %%
len(results)
# Out:
# 0

# %%
boton_mas = browser.find_element('//*[@id="btn_mas-noticias-largo ver-mas-noticias"]')
boton_mas.click()

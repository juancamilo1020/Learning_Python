# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from urllib.request import urlopen
url = "https://www.eltiempo.com/buscar?q=acuerdo+paz+farc&publishedAt%5Bfrom%5D=16-06-18&publishedAt%5Buntil%5D=16-11-18"

# %%
browser = webdriver.Chrome(r"C:\Users\jkp28\Downloads\chromedriver")
browser.get(url)
webpage = urlopen(url) 
soup = BeautifulSoup(webpage, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html>
# <head>
# <script type="text/javascript">var _sf_startpt=(new Date()).getTime()</script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="Casa Editorial El Tiempo" name="author"/>
# <meta content="News" name="genre"/>
# <meta content="Colombia" name="geo.placename"/>
# <meta content="4.570868;-74.297333" name="geo.position"/>
# <meta content="CO" name="geo.region"/>
# <meta content="notranslate" name="google"/>
# <meta content="4.570868, -74.297333" name="ICBM"/>
# <meta content="spanish" name="language"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="@ELTIEMPO" name="twitter:site"/>
# <meta content="@ELTIEMPO" name="twitter:creator"/>
# <meta content="Noticias Principales de Colombia y el Mundo - El Tiempo" name="twitter:title"/>
# ...

# %%
import re
re.findall('"(<href=/.+?)"', str(links))
# Out:
# []

# %%
main_content = soup.find('div', attrs = {'class': 'entry-content'})
content = main_content.find('ul').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-5561bf6b5cd8> in <module>()
#       1 main_content = soup.find('div', attrs = {'class': 'entry-content'})
# ----> 2 content = main_content.find('ul').text
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
tags = soup.find_all('a')
for tag in tags:
    print(tag.get('href'))
# Out:
# /
# None
# None
# https://www.eltiempo.com/login
# /zona-usuario/configurar-mis-datos
# https://suscripciones.eltiempo.com/
# /zona-usuario/mi-suscripcion
# /zona-usuario/version-impresa
# /zona-usuario/articulos-guardados
# /zona-usuario/boletines
# /zona-usuario/club-vivamos
# /preguntas-frecuentes
# None
# None
# /opinion
# /colombia
# /bogota
# /mundo
# /politica
# /justicia
# /economia
# /deportes
# /cultura
# /tecnosfera
# /vida
# http://clasificados.eltiempo.com/
# /especiales
# /multimedia/videos
# /multimedia/galeria-de-fotos
# /podcast
# /datos
# http://www.motor.com.co/
# /carrusel
# /bocas
# /lecturas-dominicales
# http://www.eltiempo.com/noticias/huella-social
# /eltiempo-television
# /pico-y-placa
# /clima
# /zona-usuario/boletines
# None
# None
# javascript:void(0)
# /zona-usuario/actualizar-email
# None
# /zona-usuario/actualizar-email
# javascript:void(0)
# None
# /buscar
# /impreso/noticias
# https://www.eltiempo.com/noticias/jep
# ...

# %%
Links = soup.findAll('a', attrs={'href': re.compile("<a class=title page-link <href=(.+) itemprop=name>")})
Links
# Out:
# []

# %%
len(tags)
# Out:
# 98

# %%
boton_mas = browser.find_element('//*[@id="btn_mas-noticias-largo ver-mas-noticias"]')
boton_mas.click()

# %% [markdown]
# # Análisis de texto

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [18.0, 8.0]

# %% [raw]
# # en iPython
# import nltk
# nltk.download()

# %%
import nltk

# %% [markdown]
# NLTK - Natural Language Toolkit:

# %% [markdown]
# http://www.nltk.org/

# %% [markdown]
# http://www.nltk.org/install.html

# %% [markdown]
# http://www.nltk.org/book/

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text1
# Out:
# <Text: Moby Dick by Herman Melville 1851>

# %%
text2
# Out:
# <Text: Sense and Sensibility by Jane Austen 1811>

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
print(text4)
# Out:
# <Text: Inaugural Address Corpus>

# %%
list(text4)
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'Senate',
#  'and',
#  'of',
#  'the',
#  'House',
#  'of',
#  'Representatives',
#  ':',
#  'Among',
#  'the',
#  'vicissitudes',
#  'incident',
#  'to',
#  'life',
#  'no',
#  'event',
#  'could',
#  'have',
#  'filled',
#  'me',
#  'with',
#  'greater',
#  'anxieties',
#  'than',
#  'that',
#  'of',
#  'which',
#  'the',
#  'notification',
#  'was',
#  'transmitted',
#  'by',
#  'your',
#  'order',
#  ',',
#  'and',
#  'received',
#  'on',
#  'the',
#  '14th',
#  'day',
#  'of',
#  'the',
#  'present',
#  'month',
#  '.',
#  'On',
#  'the',
#  'one',
#  'hand',
#  ',',
#  'I',
#  'was',
#  'summoned',
#  'by',
#  'my',
#  'Country',
#  ',',
#  'whose',
#  'voice',
#  'I',
#  'can',
#  'never',
#  'hear',
#  'but',
#  'with',
#  'veneration',
#  'and',
#  'love',
#  ',',
#  'from',
#  'a',
#  'retreat',
#  'which',
#  'I',
#  'had',
#  'chosen',
#  'with',
#  'the',
#  'fondest',
#  'predilection',
#  ',',
#  'and',
#  ',',
# ...

# %%
text1.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# ong the former , one was of a most monstrous size . ... This came towards us ,
# ON OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have r
# ll over with a heathenish array of monstrous clubs and spears . Some were thick
# d as you gazed , and wondered what monstrous cannibal and savage could ever hav
# that has survived the flood ; most monstrous and most mountainous ! That Himmal
# they might scout at Moby Dick as a monstrous fable , or still worse and more de
# th of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere l
# ing Scenes . In connexion with the monstrous pictures of whales , I am strongly
# ere to enter upon those still more monstrous stories of them which are to be fo
# ght have been rummaged out of this monstrous cabinet there is no telling . But
# of Whale - Bones ; for Whales of a monstrous size are oftentimes cast up dead u

# %%
text1.concordance("monstrous", width=90)
# Out:
# Displaying 11 of 11 matches:
#  . Among the former , one was of a most monstrous size . ... This came towards us , open
# VERSION OF THE PSALMS . " Touching that monstrous bulk of the whale or ork we have receiv
# ung all over with a heathenish array of monstrous clubs and spears . Some were thickly se
# ddered as you gazed , and wondered what monstrous cannibal and savage could ever have gon
# mass that has survived the flood ; most monstrous and most mountainous ! That Himmalehan
# ry , they might scout at Moby Dick as a monstrous fable , or still worse and more detesta
# e death of Radney .'" CHAPTER 55 Of the Monstrous Pictures of Whales . I shall ere long p
#  Whaling Scenes . In connexion with the monstrous pictures of whales , I am strongly temp
# ted here to enter upon those still more monstrous stories of them which are to be found i
# ls might have been rummaged out of this monstrous cabinet there is no telling . But a sud
# ...

# %%
text1.similar("monstrous")
# Out:
# curious fearless lamentable vexatious subtly mouldy part imperial true
# reliable lazy perilous mean delightfully passing contemptible
# domineering uncommon christian careful

# %%
text2.similar("monstrous")
# Out:
# very exceedingly so heartily extremely amazingly sweet a as good great
# remarkably vast

# %%
text2.common_contexts(["monstrous", "very"])
# Out:
# am_glad a_pretty a_lucky is_pretty be_glad

# %%
text2.concordance("monstrous")
# Out:
# Displaying 11 of 11 matches:
# . " Now , Palmer , you shall see a monstrous pretty girl ." He immediately went
# your sister is to marry him . I am monstrous glad of it , for then I shall have
# ou may tell your sister . She is a monstrous lucky girl to get him , upon my ho
# k how you will like them . Lucy is monstrous pretty , and so good humoured and
#  Jennings , " I am sure I shall be monstrous glad of Miss Marianne ' s company
#  usual noisy cheerfulness , " I am monstrous glad to see you -- sorry I could n
# t however , as it turns out , I am monstrous glad there was never any thing in
# so scornfully ! for they say he is monstrous fond of her , as well he may . I s
# possible that she should ." " I am monstrous glad of it . Good gracious ! I hav
# thing of the kind . So then he was monstrous happy , and talked on some time ab
# e very genteel people . He makes a monstrous deal of money , and they keep thei

# %%
text2.concordance("very", lines=200)
# Out:
# Displaying 200 of 500 matches:
# te was a single man , who lived to a very advanced age , and who for many year
# en made amiable himself ; for he was very young when he married , and very fon
# was very young when he married , and very fond of his wife . But Mrs . John Da
# osity to so large an amount . It was very well known that no affection was eve
# y , to be sure ," said her husband , very gravely , " that would make great di
# amily , for instance , it would be a very convenient addition ." " To be sure
# ounds on their mother ' s death -- a very comfortable fortune for any young wo
# d if they do not , they may all live very comfortably together on the interest
#  of ten thousand pounds ." " That is very true , and , therefore , I do not kn
# annuity to be paid them ; and she is very stout and healthy , and hardly forty
# , and hardly forty . An annuity is a very serious business ; it comes over and
# ...

# %%
text4.dispersion_plot(["citizens", "democracy", "freedom", "duties", "America"]);

# %% [markdown]
# https://books.google.com/ngrams

# %% [markdown]
# ### Tokens and counting

# %%
len(text3)
# Out:
# 44764

# %%
set(text3)
# Out:
# {'next',
#  'Thy',
#  'fathers',
#  'sell',
#  'discreet',
#  'poured',
#  'gave',
#  'Eliezer',
#  'Shelah',
#  'Beware',
#  'whatsoever',
#  'Hanoch',
#  'precious',
#  'Oh',
#  'Naphtali',
#  'haste',
#  'Eri',
#  'Isui',
#  'handmaidens',
#  'ride',
#  'drew',
#  'oxen',
#  'beside',
#  'unleavened',
#  'he',
#  'mourned',
#  'seasons',
#  'Almodad',
#  'magnified',
#  'An',
#  'wild',
#  'concerning',
#  'pigeon',
#  'desolate',
#  'conceived',
#  'colts',
#  'aloud',
#  'feeble',
#  'firstborn',
#  'knife',
#  'hind',
#  'strife',
#  'Zebulun',
#  'trees',
#  'only',
#  'awaked',
#  'corrupted',
#  'spake',
#  'After',
#  'restore',
#  'walking',
#  'devoured',
#  'bondman',
#  'grief',
#  'dream',
#  'vowed',
#  'Tarshish',
#  'nostrils',
#  'o',
#  'Let',
#  'goa',
#  'age',
#  'blossoms',
#  'Alvan',
#  'doest',
#  'stories',
#  'angels',
#  'For',
#  'overseer',
#  'yonder',
#  'rid',
#  'There',
#  'stead',
#  'Forgive',
#  'Hiddekel',
#  'catt',
#  'Amorite',
#  'best',
# ...

# %%
sorted(set(text3))
# Out:
# ['!',
#  "'",
#  '(',
#  ')',
#  ',',
#  ',)',
#  '.',
#  '.)',
#  ':',
#  ';',
#  ';)',
#  '?',
#  '?)',
#  'A',
#  'Abel',
#  'Abelmizraim',
#  'Abidah',
#  'Abide',
#  'Abimael',
#  'Abimelech',
#  'Abr',
#  'Abrah',
#  'Abraham',
#  'Abram',
#  'Accad',
#  'Achbor',
#  'Adah',
#  'Adam',
#  'Adbeel',
#  'Admah',
#  'Adullamite',
#  'After',
#  'Aholibamah',
#  'Ahuzzath',
#  'Ajah',
#  'Akan',
#  'All',
#  'Allonbachuth',
#  'Almighty',
#  'Almodad',
#  'Also',
#  'Alvah',
#  'Alvan',
#  'Am',
#  'Amal',
#  'Amalek',
#  'Amalekites',
#  'Ammon',
#  'Amorite',
#  'Amorites',
#  'Amraphel',
#  'An',
#  'Anah',
#  'Anamim',
#  'And',
#  'Aner',
#  'Angel',
#  'Appoint',
#  'Aram',
#  'Aran',
#  'Ararat',
#  'Arbah',
#  'Ard',
#  'Are',
#  'Areli',
#  'Arioch',
#  'Arise',
#  'Arkite',
#  'Arodi',
#  'Arphaxad',
#  'Art',
#  'Arvadite',
#  'As',
#  'Asenath',
#  'Ashbel',
#  'Asher',
#  'Ashkenaz',
#  'Ashteroth',
#  'Ask',
#  'Asshur',
#  'Asshurim',
#  'Assyr',
#  'Assyria',
# ...

# %%
len(set(text3))
# Out:
# 2789

# %% [markdown]
# ### Frequency distributions

# %%
type(text1)
# Out:
# nltk.text.Text

# %%
fdist1 = FreqDist(text1)
fdist1
# Out:
# FreqDist({'sell': 7,
#           'Savesoul': 2,
#           'Potluck': 1,
#           'APPROACHING': 1,
#           'enters': 5,
#           'habits': 4,
#           '--"': 95,
#           'deepest': 6,
#           'notice': 11,
#           'counterfeit': 1,
#           'hintings': 1,
#           'rubies': 1,
#           'trebly': 1,
#           'faint': 11,
#           'Tierce': 1,
#           'paralysis': 1,
#           '118': 1,
#           'gave': 38,
#           'ravening': 1,
#           'gloomily': 3,
#           'Saladin': 1,
#           'ticks': 1,
#           'whatsoever': 5,
#           'confining': 1,
#           'mossy': 1,
#           'produces': 1,
#           'den': 12,
#           'spot': 23,
#           'nate': 1,
#           'canes': 2,
#           'tablecloth': 1,
#           'bleeding': 3,
#           'battles': 1,
#           'invisibly': 2,
#           'drift': 1,
#           'Hygiene': 1,
#           'unhorse': 1,
#           'commentaries': 3,
# ...

# %%
fdist1.most_common(50)
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982),
#  ("'", 2684),
#  ('-', 2552),
#  ('his', 2459),
#  ('it', 2209),
#  ('I', 2124),
#  ('s', 1739),
#  ('is', 1695),
#  ('he', 1661),
#  ('with', 1659),
#  ('was', 1632),
#  ('as', 1620),
#  ('"', 1478),
#  ('all', 1462),
#  ('for', 1414),
#  ('this', 1280),
#  ('!', 1269),
#  ('at', 1231),
#  ('by', 1137),
#  ('but', 1113),
#  ('not', 1103),
#  ('--', 1070),
#  ('him', 1058),
#  ('from', 1052),
#  ('be', 1030),
#  ('on', 1005),
#  ('so', 918),
#  ('whale', 906),
#  ('one', 889),
#  ('you', 841),
#  ('had', 767),
#  ('have', 760),
#  ('there', 715),
#  ('But', 705),
#  ('or', 697),
#  ('were', 680),
#  ('now', 646),
#  ('which', 640),
#  ('?', 637),
#  ('me', 627),
#  ('like', 624)]

# %%
fdist1['whale']
# Out:
# 906

# %%
V = set(text1)
long_words = [w for w in V if len(w) > 15]
sorted(long_words)
# Out:
# ['CIRCUMNAVIGATION',
#  'Physiognomically',
#  'apprehensiveness',
#  'cannibalistically',
#  'characteristically',
#  'circumnavigating',
#  'circumnavigation',
#  'circumnavigations',
#  'comprehensiveness',
#  'hermaphroditical',
#  'indiscriminately',
#  'indispensableness',
#  'irresistibleness',
#  'physiognomically',
#  'preternaturalness',
#  'responsibilities',
#  'simultaneousness',
#  'subterraneousness',
#  'supernaturalness',
#  'superstitiousness',
#  'uncomfortableness',
#  'uncompromisedness',
#  'undiscriminating',
#  'uninterpenetratingly']

# %%
fdist5 = FreqDist(text5)

# %%
sorted(w for w in set(text5) if len(w) > 7 and fdist5[w] > 7)
# Out:
# ['#14-19teens',
#  '#talkcity_adults',
#  '((((((((((',
#  '........',
#  'Question',
#  'actually',
#  'anything',
#  'computer',
#  'cute.-ass',
#  'everyone',
#  'football',
#  'innocent',
#  'listening',
#  'remember',
#  'seriously',
#  'something',
#  'together',
#  'tomorrow',
#  'watching']

# %% [markdown]
# ### Collocations (bigrams)

# %%
text4.collocations()
# Out:
# United States; fellow citizens; four years; years ago; Federal
# Government; General Government; American people; Vice President; Old
# World; Almighty God; Fellow citizens; Chief Magistrate; Chief Justice;
# God bless; every citizen; Indian tribes; public debt; one another;
# foreign nations; political parties

# %%
text8.collocations(40)
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build; seeks lady; Late 30s; Photo pls; Vibrant personality; European
# background; year old; ASIAN LADY; country drives; intimate encounters;
# SINGLE DAD; good looking; country guy; likes cooking; poss perm; Self
# employed; East Suburbs; ship possible; quality times; Looking forward;
# fun loving

# %% [markdown]
# ### Un ejemplo a partir de un TXT

# %%
with open('acuerdo_farc.txt') as f:
    acuerdo = f.read()

# %%
print(acuerdo)
# Out:
# Acuerdo Final 24.08.2016
# ACUERDO FINAL PARA LA TERMINACIÓN DEL CONFLICTO Y LA CONSTRUCCIÓN DE UNA PAZ ESTABLE Y DURADERA
# PREÁMBULO
# Recordando que los diálogos de La Habana entre delegados y delegadas del Gobierno Nacional, presidido por el Presidente Juan Manuel Santos y delegados y delegadas de las Fuerzas Armadas Revolucionarias de Colombia-Ejército del Pueblo, con la decisión mutua de poner fin al conflicto armado nacional, tuvieron origen como resultado del Encuentro Exploratorio sucedido en la capital de la República de Cuba entre el día 23 de febrero y el día 26 de agosto de 2012;
# ...

# %%
type(acuerdo)
# Out:
# str

# %%
all_tokens = acuerdo.split()
all_tokens
# Out:
# ['Acuerdo',
#  'Final',
#  '24.08.2016',
#  'ACUERDO',
#  'FINAL',
#  'PARA',
#  'LA',
#  'TERMINACIÓN',
#  'DEL',
#  'CONFLICTO',
#  'Y',
#  'LA',
#  'CONSTRUCCIÓN',
#  'DE',
#  'UNA',
#  'PAZ',
#  'ESTABLE',
#  'Y',
#  'DURADERA',
#  'PREÁMBULO',
#  'Recordando',
#  'que',
#  'los',
#  'diálogos',
#  'de',
#  'La',
#  'Habana',
#  'entre',
#  'delegados',
#  'y',
#  'delegadas',
#  'del',
#  'Gobierno',
#  'Nacional,',
#  'presidido',
#  'por',
#  'el',
#  'Presidente',
#  'Juan',
#  'Manuel',
#  'Santos',
#  'y',
#  'delegados',
#  'y',
#  'delegadas',
#  'de',
#  'las',
#  'Fuerzas',
#  'Armadas',
#  'Revolucionarias',
#  'de',
#  'Colombia-Ejército',
#  'del',
#  'Pueblo,',
#  'con',
#  'la',
#  'decisión',
#  'mutua',
#  'de',
#  'poner',
#  'fin',
#  'al',
#  'conflicto',
#  'armado',
#  'nacional,',
#  'tuvieron',
#  'origen',
#  'como',
#  'resultado',
#  'del',
#  'Encuentro',
#  'Exploratorio',
#  'sucedido',
#  'en',
#  'la',
#  'capital',
#  'de',
#  'la',
# ...

# %%
# Dejar caracteres alfabéticos
alpha = [w for w in all_tokens if w.isalpha()]
alpha
# Out:
# ['Acuerdo',
#  'Final',
#  'ACUERDO',
#  'FINAL',
#  'PARA',
#  'LA',
#  'DEL',
#  'CONFLICTO',
#  'Y',
#  'LA',
#  'DE',
#  'UNA',
#  'PAZ',
#  'ESTABLE',
#  'Y',
#  'DURADERA',
#  'Recordando',
#  'que',
#  'los',
#  'de',
#  'La',
#  'Habana',
#  'entre',
#  'delegados',
#  'y',
#  'delegadas',
#  'del',
#  'Gobierno',
#  'presidido',
#  'por',
#  'el',
#  'Presidente',
#  'Juan',
#  'Manuel',
#  'Santos',
#  'y',
#  'delegados',
#  'y',
#  'delegadas',
#  'de',
#  'las',
#  'Fuerzas',
#  'Armadas',
#  'Revolucionarias',
#  'de',
#  'del',
#  'con',
#  'la',
#  'mutua',
#  'de',
#  'poner',
#  'fin',
#  'al',
#  'conflicto',
#  'armado',
#  'tuvieron',
#  'origen',
#  'como',
#  'resultado',
#  'del',
#  'Encuentro',
#  'Exploratorio',
#  'sucedido',
#  'en',
#  'la',
#  'capital',
#  'de',
#  'la',
#  'de',
#  'Cuba',
#  'entre',
#  'el',
#  'de',
#  'febrero',
#  'y',
#  'el',
#  'de',
#  'agosto',
#  'de',
#  'Teniendo',
#  'presente',
#  'que',
#  'como',
#  'resultado',
# ...

# %% [markdown]
# ¿Y las palabras con tilde? El anterior método es muy útil en inglés, no en español :(

# %%
import string
# Grab punctuation characters

string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
# Add additional relevant found characters to strip punctuation

punctuation = string.punctuation + '–¡¿”“•\r´'
punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~–¡¿”“•\r´'

# %%
# Strip punctuation from string

def no_punct(string):
    transtable = string.maketrans('', '', punctuation)
    return string.translate(transtable)

# %%
tokens_no_punc = list(map(no_punct, all_tokens))
tokens_no_punc
# Out:
# ['Acuerdo',
#  'Final',
#  '24082016',
#  'ACUERDO',
#  'FINAL',
#  'PARA',
#  'LA',
#  'TERMINACIÓN',
#  'DEL',
#  'CONFLICTO',
#  'Y',
#  'LA',
#  'CONSTRUCCIÓN',
#  'DE',
#  'UNA',
#  'PAZ',
#  'ESTABLE',
#  'Y',
#  'DURADERA',
#  'PREÁMBULO',
#  'Recordando',
#  'que',
#  'los',
#  'diálogos',
#  'de',
#  'La',
#  'Habana',
#  'entre',
#  'delegados',
#  'y',
#  'delegadas',
#  'del',
#  'Gobierno',
#  'Nacional',
#  'presidido',
#  'por',
#  'el',
#  'Presidente',
#  'Juan',
#  'Manuel',
#  'Santos',
#  'y',
#  'delegados',
#  'y',
#  'delegadas',
#  'de',
#  'las',
#  'Fuerzas',
#  'Armadas',
#  'Revolucionarias',
#  'de',
#  'ColombiaEjército',
#  'del',
#  'Pueblo',
#  'con',
#  'la',
#  'decisión',
#  'mutua',
#  'de',
#  'poner',
#  'fin',
#  'al',
#  'conflicto',
#  'armado',
#  'nacional',
#  'tuvieron',
#  'origen',
#  'como',
#  'resultado',
#  'del',
#  'Encuentro',
#  'Exploratorio',
#  'sucedido',
#  'en',
#  'la',
#  'capital',
#  'de',
#  'la',
# ...

# %%
# Todo en minúsculas
lower = [w.lower() for w in tokens_no_punc]
lower
# Out:
# ['acuerdo',
#  'final',
#  '24082016',
#  'acuerdo',
#  'final',
#  'para',
#  'la',
#  'terminación',
#  'del',
#  'conflicto',
#  'y',
#  'la',
#  'construcción',
#  'de',
#  'una',
#  'paz',
#  'estable',
#  'y',
#  'duradera',
#  'preámbulo',
#  'recordando',
#  'que',
#  'los',
#  'diálogos',
#  'de',
#  'la',
#  'habana',
#  'entre',
#  'delegados',
#  'y',
#  'delegadas',
#  'del',
#  'gobierno',
#  'nacional',
#  'presidido',
#  'por',
#  'el',
#  'presidente',
#  'juan',
#  'manuel',
#  'santos',
#  'y',
#  'delegados',
#  'y',
#  'delegadas',
#  'de',
#  'las',
#  'fuerzas',
#  'armadas',
#  'revolucionarias',
#  'de',
#  'colombiaejército',
#  'del',
#  'pueblo',
#  'con',
#  'la',
#  'decisión',
#  'mutua',
#  'de',
#  'poner',
#  'fin',
#  'al',
#  'conflicto',
#  'armado',
#  'nacional',
#  'tuvieron',
#  'origen',
#  'como',
#  'resultado',
#  'del',
#  'encuentro',
#  'exploratorio',
#  'sucedido',
#  'en',
#  'la',
#  'capital',
#  'de',
#  'la',
# ...

# %%
# Quitar números
alpha = [w for w in lower if not w.isdigit()]
alpha
# Out:
# ['acuerdo',
#  'final',
#  'acuerdo',
#  'final',
#  'para',
#  'la',
#  'terminación',
#  'del',
#  'conflicto',
#  'y',
#  'la',
#  'construcción',
#  'de',
#  'una',
#  'paz',
#  'estable',
#  'y',
#  'duradera',
#  'preámbulo',
#  'recordando',
#  'que',
#  'los',
#  'diálogos',
#  'de',
#  'la',
#  'habana',
#  'entre',
#  'delegados',
#  'y',
#  'delegadas',
#  'del',
#  'gobierno',
#  'nacional',
#  'presidido',
#  'por',
#  'el',
#  'presidente',
#  'juan',
#  'manuel',
#  'santos',
#  'y',
#  'delegados',
#  'y',
#  'delegadas',
#  'de',
#  'las',
#  'fuerzas',
#  'armadas',
#  'revolucionarias',
#  'de',
#  'colombiaejército',
#  'del',
#  'pueblo',
#  'con',
#  'la',
#  'decisión',
#  'mutua',
#  'de',
#  'poner',
#  'fin',
#  'al',
#  'conflicto',
#  'armado',
#  'nacional',
#  'tuvieron',
#  'origen',
#  'como',
#  'resultado',
#  'del',
#  'encuentro',
#  'exploratorio',
#  'sucedido',
#  'en',
#  'la',
#  'capital',
#  'de',
#  'la',
#  'república',
#  'de',
# ...

# %%
len(alpha)
# Out:
# 125997

# %%
len(set(alpha))
# Out:
# 7097

# %%
freqdist = nltk.FreqDist(alpha)
freqdist
# Out:
# FreqDist({'': 784,
#           'iguales': 1,
#           'consumación': 3,
#           'encargarán': 1,
#           'documentan': 1,
#           'analizará': 2,
#           'paramédico': 1,
#           'visiones': 4,
#           'informes': 59,
#           'tema': 13,
#           'estatutarias': 1,
#           'progresivas': 1,
#           'ubicados': 5,
#           'comprueba': 1,
#           'corresponsabilidad': 4,
#           'seguimientos': 1,
#           'riego': 11,
#           'nuevo': 67,
#           'oscuridad': 1,
#           'entenderá': 3,
#           'obligadas': 2,
#           'alternativos': 4,
#           'acogido': 1,
#           'plenamente': 8,
#           'reino': 5,
#           'incorporarán': 4,
#           'congreso': 18,
#           'establecida': 2,
#           'pudiendo': 6,
#           'fuerte': 2,
#           'universitarios': 1,
#           'oferta': 10,
#           'intervención': 9,
#           'consolidar': 7,
#           'respaldar': 1,
# ...

# %%
freqdist.most_common()
# Out:
# [('de', 11912),
#  ('la', 6387),
#  ('y', 6334),
#  ('el', 4004),
#  ('las', 3718),
#  ('en', 3389),
#  ('los', 2929),
#  ('a', 2345),
#  ('que', 2249),
#  ('del', 2214),
#  ('para', 1862),
#  ('se', 1287),
#  ('con', 1281),
#  ('acuerdo', 1024),
#  ('por', 989),
#  ('o', 897),
#  ('', 784),
#  ('nacional', 651),
#  ('un', 583),
#  ('al', 561),
#  ('farcep', 551),
#  ('una', 527),
#  ('como', 520),
#  ('final', 516),
#  ('gobierno', 513),
#  ('paz', 502),
#  ('no', 500),
#  ('su', 497),
#  ('lo', 429),
#  ('especial', 361),
#  ('sus', 356),
#  ('derechos', 353),
#  ('seguridad', 350),
#  ('conflicto', 328),
#  ('página', 298),
#  ('organizaciones', 295),
#  ('medidas', 294),
#  ('este', 294),
#  ('participación', 278),
#  ('e', 273),
#  ('implementación', 265),
#  ('política', 265),
#  ('mmv', 258),
#  ('sobre', 256),
#  ('entre', 239),
#  ('personas', 231),
#  ('comunidades', 223),
#  ('fin', 222),
#  ('sistema', 220),
#  ('jurisdicción', 213),
#  ('información', 213),
# ...

# %%
from nltk.corpus import stopwords
# Grab stopwords in Spanish
stopwords_esp = stopwords.words('spanish')
stopwords_esp
# Out:
# ['de',
#  'la',
#  'que',
#  'el',
#  'en',
#  'y',
#  'a',
#  'los',
#  'del',
#  'se',
#  'las',
#  'por',
#  'un',
#  'para',
#  'con',
#  'no',
#  'una',
#  'su',
#  'al',
#  'lo',
#  'como',
#  'más',
#  'pero',
#  'sus',
#  'le',
#  'ya',
#  'o',
#  'este',
#  'sí',
#  'porque',
#  'esta',
#  'entre',
#  'cuando',
#  'muy',
#  'sin',
#  'sobre',
#  'también',
#  'me',
#  'hasta',
#  'hay',
#  'donde',
#  'quien',
#  'desde',
#  'todo',
#  'nos',
#  'durante',
#  'todos',
#  'uno',
#  'les',
#  'ni',
#  'contra',
#  'otros',
#  'ese',
#  'eso',
#  'ante',
#  'ellos',
#  'e',
#  'esto',
#  'mí',
#  'antes',
#  'algunos',
#  'qué',
#  'unos',
#  'yo',
#  'otro',
#  'otras',
#  'otra',
#  'él',
#  'tanto',
#  'esa',
#  'estos',
#  'mucho',
#  'quienes',
#  'nada',
#  'muchos',
#  'cual',
#  'poco',
#  'ella',
#  'estar',
#  'estas',
#  'algunas',
#  'algo',
#  'nosotros',
#  'mi',
#  'mis',
#  'tú',
#  'te',
#  'ti',
#  'tu',
#  'tus',
#  'ellas',
#  'nosotras',
#  'vosostros',
# ...

# %%
# Filter list of all tokens based on list of words of interest

tokens_no_stop = [w for w in alpha if w not in stopwords_esp]
tokens_no_stop
# Out:
# ['acuerdo',
#  'final',
#  'acuerdo',
#  'final',
#  'terminación',
#  'conflicto',
#  'construcción',
#  'paz',
#  'estable',
#  'duradera',
#  'preámbulo',
#  'recordando',
#  'diálogos',
#  'habana',
#  'delegados',
#  'delegadas',
#  'gobierno',
#  'nacional',
#  'presidido',
#  'presidente',
#  'juan',
#  'manuel',
#  'santos',
#  'delegados',
#  'delegadas',
#  'fuerzas',
#  'armadas',
#  'revolucionarias',
#  'colombiaejército',
#  'pueblo',
#  'decisión',
#  'mutua',
#  'poner',
#  'fin',
#  'conflicto',
#  'armado',
#  'nacional',
#  'origen',
#  'resultado',
#  'encuentro',
#  'exploratorio',
#  'sucedido',
#  'capital',
#  'república',
#  'cuba',
#  'día',
#  'febrero',
#  'día',
#  'agosto',
#  'presente',
#  'resultado',
#  'diálogos',
#  'exploratorios',
#  'referidos',
#  'produjo',
#  'acuerdo',
#  'general',
#  'terminación',
#  'conflicto',
#  'construcción',
#  'paz',
#  'estable',
#  'duradera',
#  'firmado',
#  'fecha',
#  'última',
#  'citada',
# ...

# %%
freqdist = nltk.FreqDist(tokens_no_stop)
freqdist.most_common()
# Out:
# [('acuerdo', 1024),
#  ('', 784),
#  ('nacional', 651),
#  ('farcep', 551),
#  ('final', 516),
#  ('gobierno', 513),
#  ('paz', 502),
#  ('especial', 361),
#  ('derechos', 353),
#  ('seguridad', 350),
#  ('conflicto', 328),
#  ('página', 298),
#  ('organizaciones', 295),
#  ('medidas', 294),
#  ('participación', 278),
#  ('implementación', 265),
#  ('política', 265),
#  ('mmv', 258),
#  ('personas', 231),
#  ('comunidades', 223),
#  ('fin', 222),
#  ('sistema', 220),
#  ('jurisdicción', 213),
#  ('información', 213),
#  ('víctimas', 212),
#  ('integral', 210),
#  ('así', 203),
#  ('manera', 203),
#  ('proceso', 201),
#  ('armas', 200),
#  ('desarrollo', 196),
#  ('integrantes', 190),
#  ('comisión', 187),
#  ('parte', 184),
#  ('marco', 184),
#  ('ser', 182),
#  ('verdad', 182),
#  ('zvtn', 178),
#  ('humanos', 178),
#  ('da', 177),
#  ('garantizar', 174),
#  ('verificación', 173),
#  ('cumplimiento', 173),
#  ('justicia', 173),
#  ('internacional', 171),
# ...

# %%
# From inspection of frequency distribution, make list of words of interest

not_of_interest = ['','página','mmv','así','zvtn','da']

# %%
# Filter list of all tokens based on list of words of interest

tokens_of_interest = [w for w in tokens_no_stop if w not in not_of_interest]
tokens_of_interest
# Out:
# ['acuerdo',
#  'final',
#  'acuerdo',
#  'final',
#  'terminación',
#  'conflicto',
#  'construcción',
#  'paz',
#  'estable',
#  'duradera',
#  'preámbulo',
#  'recordando',
#  'diálogos',
#  'habana',
#  'delegados',
#  'delegadas',
#  'gobierno',
#  'nacional',
#  'presidido',
#  'presidente',
#  'juan',
#  'manuel',
#  'santos',
#  'delegados',
#  'delegadas',
#  'fuerzas',
#  'armadas',
#  'revolucionarias',
#  'colombiaejército',
#  'pueblo',
#  'decisión',
#  'mutua',
#  'poner',
#  'fin',
#  'conflicto',
#  'armado',
#  'nacional',
#  'origen',
#  'resultado',
#  'encuentro',
#  'exploratorio',
#  'sucedido',
#  'capital',
#  'república',
#  'cuba',
#  'día',
#  'febrero',
#  'día',
#  'agosto',
#  'presente',
#  'resultado',
#  'diálogos',
#  'exploratorios',
#  'referidos',
#  'produjo',
#  'acuerdo',
#  'general',
#  'terminación',
#  'conflicto',
#  'construcción',
#  'paz',
#  'estable',
#  'duradera',
#  'firmado',
#  'fecha',
#  'última',
#  'citada',
# ...

# %%
# Si queremos aplicar métodos de objetos nltk.Text:
tokens_nltk = nltk.Text(tokens_of_interest)
tokens_nltk
# Out:
# <Text: acuerdo final acuerdo final terminación conflicto construcción paz...>

# %% [markdown]
# ---

# %% [markdown]
# Nube de palabras:

# %%
# Join list in string

tokens_of_interest_str = ' '.join(tokens_of_interest)
tokens_of_interest_str
# Out:
# 'acuerdo final acuerdo final terminación conflicto construcción paz estable duradera preámbulo recordando diálogos habana delegados delegadas gobierno nacional presidido presidente juan manuel santos delegados delegadas fuerzas armadas revolucionarias colombiaejército pueblo decisión mutua poner fin conflicto armado nacional origen resultado encuentro exploratorio sucedido capital república cuba día febrero día agosto presente resultado diálogos exploratorios referidos produjo acuerdo general terminación conflicto construcción paz estable duradera firmado fecha última citada testigos nacionales delegados república cuba reino noruega sirvieron igualmente testigos entonces asienten proceso países garantes poniendo presente república bolivariana venezuela república chile aprestado momento buenos oficios países acompañantes recordando desarrollo agenda aprobada acuerdo mención dio inicio mesa conversaciones día octubre ciudad oslo capital reino noruega luego continua
# ...

# %%
# Write to txt file

with open('tokens_of_interest_str.txt', 'a') as f:
    f.write(tokens_of_interest_str)

# %%
# Based on https://github.com/amueller/word_cloud/blob/master/examples/masked.py
# Word cloud requirements

from os import path
from wordcloud import WordCloud

d = path.dirname('/Users/Santiago/Dropbox/Clases/URosario/2018-II/repo_mcpp_2018_2/notebooks/tokens_of_interest_str.txt')

# Read the whole text
text = open(path.join(d, 'tokens_of_interest_str.txt')).read()

wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")

# take relative word frequencies into account, lower max_font_size
wordcloud = WordCloud(max_font_size=40, relative_scaling=.5).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-1fa22dfd6301> in <module>()
#       3
#       4 from os import path
# ----> 5 from wordcloud import WordCloud
#       6
#       7 d = path.dirname('/Users/Santiago/Dropbox/Clases/URosario/2018-II/repo_mcpp_2018_2/notebooks/tokens_of_interest_str.txt')
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# Volviendo al texto inicial, completo:

# %%
acuerdo_nltk = nltk.Text(acuerdo.split())
acuerdo_nltk
# Out:
# <Text: Acuerdo Final 24.08.2016 ACUERDO FINAL PARA LA TERMINACIÓN...>

# %%
acuerdo_nltk.dispersion_plot(["conflicto", "rural", "justicia", "derechos", "seguridad", "paz"])

# %%
acuerdo_nltk.concordance('género')
# Out:
# Displaying 25 of 41 matches:
# de la ciudadanía con un enfoque de género y como consecuencia garantice la no
# bién que se promueva la equidad de género mediante la adopción de medidas es
# foque territorial, diferencial y de género que implica reconocer y tener en cu
#  orientación sexual e identidad de género diversa— y garantizar la sostenibil
#  enfoque territorial, el enfoque de género y la diversidad étnica y cultural
#  orientación sexual e identidad de género diversa, y condición de discapacid
# a pobreza deberán tener enfoque de género que permita hacer frente a las nece
#  orientación sexual e identidad de género diversa y en condición de discapac
# , que cuente con una perspectiva de género que permita a las mujeres superar b
# , que cuente con una perspectiva de género que promueva el empoderamiento econ
# ́ticos, con enfoque diferencial, de género y con presencia nacional y regional
# ...

# %%
acuerdo_nltk.count('género')
# Out:
# 40

# %%
acuerdo_nltk.concordance('género', lines=41)
# Out:
# Displaying 41 of 41 matches:
# de la ciudadanía con un enfoque de género y como consecuencia garantice la no
# bién que se promueva la equidad de género mediante la adopción de medidas es
# foque territorial, diferencial y de género que implica reconocer y tener en cu
#  orientación sexual e identidad de género diversa— y garantizar la sostenibil
#  enfoque territorial, el enfoque de género y la diversidad étnica y cultural
#  orientación sexual e identidad de género diversa, y condición de discapacid
# a pobreza deberán tener enfoque de género que permita hacer frente a las nece
#  orientación sexual e identidad de género diversa y en condición de discapac
# , que cuente con una perspectiva de género que permita a las mujeres superar b
# , que cuente con una perspectiva de género que promueva el empoderamiento econ
# ́ticos, con enfoque diferencial, de género y con presencia nacional y regional
# ...

# %% [markdown]
# ----
